# %%
from maths import*
    def calcul(a,b):
    c=(a**2+b**2)**(1/2)
    return c
def pythagore (a,b):
    if(type(a)==str or type(b)==str):
        print("str ne fonctionne pas")
        print("entrez un valeur numérique")
        if(type(a)==str)&(type(b)==int):
            while(type(a)==str)&(type(b)==int)
            try:
                a-int(input())
                except Error:
                    print("n'est pas un int ")
                    a=int (input())    
        elif(type(b)==str)&(type(a)=-int):
            while(type(b)==-str)&(type(a)==int):
                try:
                    b=int(input())
                    except Error:
                        print("n'est pas un int ")
                        b=int(input())
            else:
                a=int(input())
                b=int(input())
            return calcul(a,b)
# Out:
#   File "<ipython-input-2-fd056a94c63b>", line 2
#     def calcul(a,b):
#     ^
# IndentationError: unexpected indent
